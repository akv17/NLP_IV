# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками с помощью LDA в gensim и NMF в sklearn**.
#
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор);
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases,  можно также попробовать другие способы построить нграммы);
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;
#
# 6) между словарем и обучением модели добавьте tfidf (`gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]`);
#
# 7) повторите пункт 4 на преобразованном корпусе;
#
# 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)
#
# 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем
#
# 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 5, 8 и 10. (2, 3, 2 баллов соответственно). Чтобы заработать остальные 3 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **

# %%
import gensim
import json
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

from mystem import MyStem
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
_mystem = MyStem()

# %% [markdown]
# ## Данные

# %%
stops = set(stopwords.words('russian')) | {'gt',}
def remove_tags(text):
    return re.sub(r'<[^>]+>|gt', '', text)

def normalize(words):
    norm_words = [morph.parse(word)[0].normal_form for word in words if len(set(word)) > 1]
    return norm_words

def opt_normalize(texts, top=None):
    uniq = Counter()
    for text in texts:
        uniq.update(text)
    
    norm_uniq = {word:morph.parse(word)[0].normal_form for word, _ in uniq.most_common(top)}
    
    norm_texts = []
    for text in texts:
        
        norm_words = [norm_uniq.get(word) for word in text]
        norm_words = [word for word in norm_words if word and word not in stops]
        norm_texts.append(norm_words)
        
    return norm_texts

def tokenize(text):
    words = [word.strip(string.punctuation) for word in text.split()]
    words = [word for word in words if word]
    
    return words

# %% [markdown]
# Возьмем 4 тыс статьи с Хабра. Это мало для хорошей тематической модели, но иначе у нас просто ничего не обучится за семинар.

# %%
data_raw = open('habr_texts.txt', encoding='utf-8').read().splitlines()

# %%
data_raw = [remove_tags(doc) for doc in data_raw]

# %% [markdown]
# В текстах есть тэги. Потрем их. Ещё токенизируем самым простым способом и нормализуем Pymorphy.

# %%
# %%time
data_norm = _mystem.run(data_raw, flags='-idln', remove_stopwords=True)
# Out:
# Wall time: 2min 4s

# %%
data_norm = [doc.split() for doc in data_norm]

# %% [markdown]
# ### Тематическое моделирование в gensim

# %%
def lda_gensim(data, freq_thresh=0.3, ngrams_thresh=0.4, tfidf=False, model_params=None):
    _model_params = {
        'num_topics': 10,
        'workers': 3,
        'passes': 10,
        'eta': 'auto',
        'iterations': 20
    }
    _data = data
    
    if model_params is not None:
        _model_params.update(model_params)
    
    if ngrams_thresh is not None:
        ph = gensim.models.Phrases(_data, scoring='npmi', threshold=ngrams_thresh)
        p = gensim.models.phrases.Phraser(ph)
        _data = p[_data]
    
    dictionary = gensim.corpora.Dictionary(_data)
    dictionary.filter_extremes(no_above=freq_thresh)
    dictionary.compactify()
    
    corpus = [dictionary.doc2bow(text) for text in _data]
    
    if tfidf:
        _tfidf = gensim.models.TfidfModel(corpus, id2word=dictionary)
        corpus = _tfidf[corpus]
        
    lda = gensim.models.LdaMulticore(
            corpus=corpus,
            id2word=dictionary,
            random_state=17,
            **_model_params
    )
    
    return lda

# %% [markdown]
# Построим модель на 10 тем

# %%
# %%time
lda10 = lda_gensim(data_norm)
# Out:
# Wall time: 1min 5s

# %% [markdown]
# Посмотрим на темы

# %%
lda10.print_topics()
# Out:
# [(0,
#   '0.026*"lt" + 0.009*"if" + 0.007*"return" + 0.006*"name" + 0.005*"i" + 0.005*"id" + 0.005*"this" + 0.004*"int" + 0.004*"файл" + 0.004*"класс"'),
#  (1,
#   '0.007*"сайт" + 0.004*"товар" + 0.003*"игрок" + 0.003*"клиент" + 0.003*"скидка" + 0.003*"день" + 0.003*"страница" + 0.003*"игра" + 0.003*"участник" + 0.003*"интерфейс"'),
#  (2,
#   '0.009*"устройство" + 0.004*"модель" + 0.003*"смартфон" + 0.003*"камера" + 0.003*"вселенная" + 0.003*"технология" + 0.002*"энергия" + 0.002*"производитель" + 0.002*"модуль" + 0.002*"сигнал"'),
#  (3,
#   '0.004*"объект" + 0.004*"точка" + 0.002*"изображение" + 0.002*"размер" + 0.002*"элемент" + 0.002*"скорость" + 0.002*"земля" + 0.002*"материал" + 0.002*"печать" + 0.002*"модель"'),
#  (4,
#   '0.006*"and" + 0.005*"игра" + 0.005*"the" + 0.004*"of" + 0.004*"to" + 0.004*"for" + 0.003*"файл" + 0.003*"доклад" + 0.003*"VR" + 0.003*"a"'),
#  (5,
#   '0.012*"игра" + 0.005*"сервер" + 0.003*"какой-то" + 0.003*"память" + 0.003*"игрок" + 0.003*"производительность" + 0.002*"программа" + 0.002*"запрос" + 0.002*"процессор" + 0.002*"изменение"'),
#  (6,
#   '0.005*"сеть" + 0.004*"технология" + 0.004*"сервис" + 0.003*"рынок" + 0.003*"клиент" + 0.003*"бизнес" + 0.003*"интернет" + 0.003*"сайт" + 0.003*"модель" + 0.003*"услуга"'),
#  (7,
#   '0.009*"файл" + 0.006*"сервер" + 0.005*"устройство" + 0.004*"настройка" + 0.003*"запрос" + 0.003*"устанавливать" + 0.003*"доступ" + 0.003*"сайт" + 0.003*"up" + 0.003*"Windows"'),
#  (8,
#   '0.010*"значение" + 0.005*"метод" + 0.005*"объект" + 0.005*"элемент" + 0.004*"строка" + 0.004*"ошибка" + 0.004*"класс" + 0.003*"язык" + 0.003*"переменный" + 0.003*"a"'),
#  (9,
#   '0.003*"продукт" + 0.002*"что-то" + 0.002*"день" + 0.002*"клиент" + 0.002*"какой-то" + 0.002*"жизнь" + 0.002*"исследование" + 0.002*"сотрудник" + 0.002*"игра" + 0.002*"заниматься"')]

# %% [markdown]
# В целом темы кажутся осмысленными, однако во многих из них повторяется веб-тематика.
# Помимо этого, некоторые темы забиты кодом, которого в данных очень много.
# Возможно, для повышения качества тем следует избавиться от кода в данных и несколько изменить порог частотности при построении словаря

# %% [markdown]
# Так как в данных участки кода никак не помечены, я не вижу никакого иного способа избавиться от кода, кроме как удалить латинские символы

# %%
data_norm2 = [
    re.sub('[a-zA-Z]', '', ' '.join(doc)).split() for doc in data_norm
]

# %% [markdown]
# Построим теперь модели на 10, 25, 50 и 100 тем со сниженным порогом вероятности и `npmi`

# %%
# %%time
lda_res = {
    i: lda_gensim(data_norm2, freq_thresh=0.25, ngrams_thresh=0.3, model_params={'num_topics': i, 'passes': 20})
    for i in [10, 25, 50, 100]
}
# Out:
# Wall time: 6min 3s

# %% [markdown]
# Посмотрим на них (на топ-10 самых важных для каждой модели)

# %%
for i, lda in lda_res.items():
    print('%s:\n%s\n' % ('LDA %s' % i, lda.print_topics(10)))
# Out:
# LDA 10:
# [(0, '0.007*"клиент" + 0.007*"сеть" + 0.006*"сервис" + 0.005*"сервер" + 0.004*"услуга" + 0.004*"безопасность" + 0.004*"бизнес" + 0.003*"управление" + 0.003*"трафик" + 0.003*"инфраструктура"'), (1, '0.006*"алгоритм" + 0.005*"объект" + 0.005*"элемент" + 0.005*"модель" + 0.004*"точка" + 0.003*"реализация" + 0.003*"класс" + 0.003*"изображение" + 0.003*"тестирование" + 0.003*"подход"'), (2, '0.007*"сообщение" + 0.006*"модель" + 0.006*"страница" + 0.005*"запрос" + 0.005*"бот" + 0.005*"элемент" + 0.004*"сервис" + 0.004*"документ" + 0.004*"текст" + 0.004*"сеть"'), (3, '0.007*"класс" + 0.006*"запрос" + 0.006*"объект" + 0.005*"библиотека" + 0.005*"строка" + 0.005*"компонент" + 0.004*"модуль" + 0.004*"элемент" + 0.004*"параметр" + 0.004*"память"'), (4, '0.013*"сервер" + 0.007*"настройка" + 0.005*"адрес" + 0.005*"скрипт" + 0.004*"установка" + 0.004*"клиент" + 0.003*"настраивать" + 0.003*"сервис" + 0.003*"указывать" + 0.003*"пароль"'), (5, '0.003*"страна" + 0.003*"мир" + 0.003*"робот" + 0.002*"сша" + 0.002*"ученый" + 0.002*"россия" + 0.002*"город" + 0.002*"земля" + 0.002*"спутник" + 0.002*"машина"'), (6, '0.009*"объект" + 0.004*"вселенная" + 0.004*"точка" + 0.003*"алгоритм" + 0.003*"звезда" + 0.003*"теория" + 0.003*"скорость" + 0.003*"пространство" + 0.003*"блок" + 0.002*"галактика"'), (7, '0.004*"камера" + 0.004*"модель" + 0.004*"сигнал" + 0.004*"звук" + 0.003*"смартфон" + 0.003*"датчик" + 0.003*"производитель" + 0.003*"режим" + 0.003*"плата" + 0.002*"процессор"'), (8, '0.003*"книга" + 0.003*"жизнь" + 0.003*"программист" + 0.003*"мозг" + 0.002*"сотрудник" + 0.002*"день" + 0.002*"ребенок" + 0.002*"заниматься" + 0.002*"доклад" + 0.002*"опыт"'), (9, '0.020*"игра" + 0.007*"игрок" + 0.005*"продукт" + 0.003*"дизайн" + 0.003*"рынок" + 0.002*"история" + 0.002*"мир" + 0.002*"играть" + 0.002*"экран" + 0.002*"печать"')]
ельный"'), (67, '0.014*"заказчик" + 0.013*"бизнес" + 0.010*"услуга" + 0.009*"месяц" + 0.008*"документ" + 0.008*"деньги" + 0.008*"сумма" + 0.008*"рубль" + 0.007*"доход" + 0.006*"сотрудник"'), (65, '0.046*"программист" + 0.036*"программирование" + 0.026*"язык" + 0.015*"математика" + 0.014*"язык_программирование" + 0.009*"ребенок" + 0.008*"знание" + 0.007*"математический" + 0.005*"область" + 0.005*"математик"'), (66, '0.022*"ия" + 0.012*"искусственный_интеллект" + 0.007*"университет_итмо" + 0.006*"естественный_язык" + 0.005*"научный" + 0.005*"университет" + 0.004*"нейросеть" + 0.003*"ученый" + 0.003*"область" + 0.003*"лицо"'), (51, '0.027*"мозг" + 0.012*"животное" + 0.012*"бумага" + 0.010*"ученый" + 0.007*"лицо" + 0.007*"клетка" + 0.007*"глаз" + 0.006*"мышь" + 0.005*"электрод" + 0.005*"нейрон"'), (84, '0.037*"транзакция" + 0.014*"запрос" + 0.013*"запись" + 0.009*"таблица" + 0.008*"база_данные" + 0.006*"модуль" + 0.005*"тэг" + 0.005*"блокировка" + 0.004*"чтение" + 0.004*"ртуть"')]

# %% [markdown]
# Видно, что качество тем улучшилось и каждая модель способна выделить осмысленные темы касательно веб-разработки, струтктурного программирования, машинного обучения, техники и устройств, бизнеса и даже карьерного развития.
# Также начали появляться устойчивые словосочетания, которых вообще не было ранее.
# Как мне кажется, тремя наиболее интересными и хорошими темами оказались темы LDA25 модели:
# - бэкэнд-разработка:
# (18, '0.013*"сервер" + 0.013*"т_е" + 0.009*"запрос" + 0.007*"база__данные" + 0.005*"сервис" + 0.005*"очередь" + 0.004*"токен" + 0.004*"либо" + 0.003*"клиент" + 0.003*"сессия"')
#
# - машинное обучение:
# (2, '0.015*"модель" + 0.010*"сеть" + 0.009*"обучение" + 0.008*"бот" + 0.007*"изображение" + 0.007*"признак" + 0.006*"нейрон" + 0.005*"алгоритм" + 0.005*"слой" + 0.005*"обучать"')
#
# - полеты в космос:
# (12, '0.010*"спутник" + 0.006*"ракета" + 0.005*"запуск" + 0.005*"двигатель" + 0.004*"пуск" + 0.004*"орбита" + 0.003*"космос" + 0.003*"транзистор" + 0.003*"ракета_носитель" + 0.003*"космический"')
#
# Касательно изменений в сравнении с предыдущим пайплайном, по LDA10 модели видно, что темы стали лучше, более полноценными и независимыми друг от друга, появились устойчивые словосочетания, нейтрализовалась доминация веб тематики и темы более не засорены кодом. Также появились и новые полноценные темы, например, космоса или карьерного роста (что интересно получилось (тема 8))

# %% [markdown]
# Добавим теперь `tfidf` и повторим эксперимент

# %%
# %%time
lda_res2 = {
    i: lda_gensim(
        data_norm2,
        freq_thresh=0.25,
        ngrams_thresh=0.3,
        tfidf=True,
        model_params={'num_topics': i, 'passes': 20})
    for i in [10, 25, 50, 100]
}
# Out:
# Wall time: 16min 59s

# %%
for i, lda in lda_res2.items():
    print('%s:\n%s\n' % ('LDA %s' % i, lda.print_topics(10)))
# Out:
# LDA 10:
ма_подписка" + 0.001*"последовательный_порт" + 0.001*"префронтальный_кора" + 0.001*"кардинальный_изменение" + 0.000*"скачать_распаковывать" + 0.000*"высокий_образование" + 0.000*"жениться" + 0.000*"тестирование_распределенный"'), (3, '0.001*"микросервис" + 0.001*"колонна" + 0.001*"капитализация" + 0.001*"торрент_трекер" + 0.001*"чашка" + 0.001*"веб_служба" + 0.000*"пивот" + 0.000*"осанка" + 0.000*"китайский_правительство" + 0.000*"блок"'), (17, '0.001*"обучение_подкрепление" + 0.001*"посылать_запрос" + 0.001*"фас" + 0.001*"предыдущий_публикация" + 0.001*"статический_метод" + 0.001*"сеттер" + 0.001*"предписание" + 0.001*"условие_выборка" + 0.001*"многомерный_пространство" + 0.001*"водоросль"'), (47, '0.001*"шорткат" + 0.001*"аксессор" + 0.001*"дочерний_процесс" + 0.001*"фрод" + 0.001*"см_фото" + 0.001*"стеганография" + 0.000*"астронавт" + 0.000*"нано" + 0.000*"митап" + 0.000*"ход_выполнение"'), (11, '0.001*"пожалуйста_почта" + 0.001*"предыдущий_дайджест" + 0.001*"рассылка_подписываться" + 0.001*"дайджест_доступный" + 0.001*"ошибка_присылать" + 0.001*"аналитик_маркетинг" + 0.001*"валидатор" + 0.001*"сетевой_стек" + 0.001*"роут" + 0.001*"уровень_изоляция"')]
#
# LDA 100:
# [(11, '0.002*"ширина_канал" + 0.001*"р" + 0.001*"книга_райан" + 0.001*"макдермот" + 0.001*"предпринимательство" + 0.001*"тестирование_форматирование" + 0.001*"асинхронность_обработка" + 0.001*"эстония" + 0.001*"рафаэль" + 0.001*"внешний_антенна"'), (37, '0.002*"симметрия" + 0.002*"кремний" + 0.001*"портфолио" + 0.001*"аксессор" + 0.001*"фермент" + 0.001*"продюсер" + 0.001*"отпускной" + 0.001*"геймдизайнер" + 0.001*"линейный_интерполяция" + 0.001*"хабраэффект"'), (39, '0.001*"голосовой_помощник" + 0.001*"ошейник" + 0.001*"выходной_сигнал" + 0.001*"жидкий_кислород" + 0.001*"шина" + 0.001*"вводить_адресный" + 0.001*"средний_школа" + 0.001*"конечный_автомат" + 0.001*"общаться_друг" + 0.001*"наведение_курсор"'), (61, '0.002*"капча" + 0.002*"чернила" + 0.002*"Код_имя" + 0.001*"пользовательский_режим" + 0.001*"ачивко" + 0.001*"кросс_платформенный" + 0.001*"ачивки" + 0.001*"задание_агент" + 0.001*"вычитывать" + 0.001*"числовой_формат"'), (1, '0.002*"отправка_смс" + 0.002*"БС" + 0.002*"зуб" + 0.001*"касса" + 0.001*"мсек" + 0.001*"дочерний_процесс" + 0.001*"смс" + 0.001*"базовый_станция" + 0.001*"прокси_класс" + 0.001*"ростелеком"'), (67, '0.002*"байткод" + 0.002*"распаковывать" + 0.002*"лентикула" + 0.002*"вдох" + 0.001*"шпатель" + 0.001*"латвия" + 0.001*"выдох" + 0.001*"фонд" + 0.001*"рига" + 0.001*"документировать"'), (65, '0.002*"ранний_доступ" + 0.001*"альбом" + 0.001*"галерея" + 0.001*"одиночество" + 0.001*"задний_камера" + 0.001*"многопоточный_программирование" + 0.001*"нетбук" + 0.001*"аудит_безопасность" + 0.001*"раздел_математика" + 0.001*"отец_основатель"'), (66, '0.004*"университет_итмо" + 0.004*"олимпиада" + 0.002*"весы" + 0.002*"специалист_информационный" + 0.002*"игровой_поле" + 0.002*"тренировать" + 0.002*"ЦА" + 0.002*"итмо" + 0.002*"реквизит" + 0.002*"хейтер"'), (51, '0.003*"распродажа" + 0.002*"полиция" + 0.002*"инстанс" + 0.002*"бесплатный_доставка" + 0.002*"партнерский_программа" + 0.002*"интегратор" + 0.002*"чистый_архитектура" + 0.002*"распределенный_система" + 0.001*"телефонный_номер" + 0.001*"преподавать"'), (84, '0.002*"трансивер" + 0.002*"скафандр" + 0.002*"лизинг" + 0.001*"система_счисление" + 0.001*"аутентифицировать" + 0.001*"сворачивание" + 0.001*"макет" + 0.001*"скроллинг" + 0.001*"промокод" + 0.001*"куб"')]

# %% [markdown]
# Добавление `tfidf`, к сожалению, не позволило улучшить качество, но, наоборот, только ухудшило.
# Появились совершенно бессмысленные темы, а во многих осмысленных появилось немало шума.
# Но некоторые сильные тематики, такие, как веб- и структурная разработка, по-прежнему выделяются довольно хорошо и полноценно.

# %% [markdown]
# ### Разложение матриц в sklearn

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %% [markdown]
# Sklearn принимает на вход строки, поэтому склеим наши списки.

# %%
data_norm3 = [' '.join(text) for text in data_norm2]

# %%
def nmf(data, n_components=10, vectorizer_params=None, alpha=0):
    _vectorizer_params = {
        'max_features': 10000,
        'min_df': 10,
        'max_df': 0.2,
        'lowercase': False
    }
    
    if vectorizer_params is not None:
        _vectorizer_params.update(vectorizer_params)
        
    vectorizer = TfidfVectorizer(**_vectorizer_params)
    X = vectorizer.fit_transform(data)
    
    model = NMF(n_components, random_state=17, alpha=alpha)
    model.fit(X)
    
    return model, vectorizer

def get_nmf_topics(model, vectorizer, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(model.n_components):
        
        #топ n слов для темы.
        words_ids = model.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %% [markdown]
# Запустим `NMF` на 10, 25, 50 и 100 тем, а также несколько изменим частотные параметры векторизатора, также добавив биграммы.

# %%
# %%time
nmf_res = {
    i: nmf(data_norm3, n_components=i, vectorizer_params={'ngram_range': (1, 2)})
    for i in [10, 25, 50, 100]
}
# Out:
# Wall time: 2min 4s

# %% [markdown]
# Посмотрим на темы

# %%
for i, _nmf in nmf_res.items():
    print('%s:\n%s\n' % ('NMF %s' % i, get_nmf_topics(*_nmf, 10)))
# Out:
# NMF 10:
#    Topic # 01    Topic # 02  Topic # 03    Topic # 04          Topic # 05  \
# 0      бизнес          игра       класс      обучение         виртуальный
# 1       рынок         игрок      запрос            ия                диск
# 2   сотрудник       игровой      строка          мозг              машина
# 3      услуга        играть  библиотека         робот  виртуальный машина
# 4    блокчейн      персонаж   компонент        ученый              память
# 5      деньги        движок    страница     нейросеть           резервный
# 6     продажа  игра который      модуль      алгоритм                  ВМ
# 7  российский     мобильный       вызов  исследование              облако
# 8   мобильный          жанр     таблица     интеллект  производительность
# 9      страна     приставка        тест     нейронный                ядро
#
#     Topic # 06     Topic # 07        Topic # 08   Topic # 09    Topic # 10
# 0       камера     уязвимость             книга  космический        доклад
# 1     смартфон          атака          менеджер      спутник   конференция
# 2         звук         пароль            читать       орбита        спикер
# 3        плата   безопасность  профессиональный        земля   выступление
# 4        экран           ключ   порекомендовать      планета         видео
# 5      дисплей      сообщение       сколько час         марс      участник
# 6      телефон            бот      пользоваться       ракета       встреча
# 7  аккумулятор          адрес      предпочитать    вселенная   мероприятие
# 8       датчик     сертификат             совет      аппарат         слайд
# 9       корпус  злоумышленник       программист      энергия  тестирование
#
# NMF 25:
#    Topic # 01    Topic # 02  Topic # 03    Topic # 04             Topic # 05  \
# 0       рынок          игра       класс          мозг            виртуальный
# 1      бизнес         игрок       вызов       пациент                 машина
# 2  российский       игровой    свойство        ученый     виртуальный машина
# 3      страна        играть      строка        клетка                     ВМ
# 4   мобильный      персонаж      массив   заболевание              резервный
# 5      россия        движок  библиотека  исследование  резервный копирование
# 6      деньги  игра который  переменный       болезнь                   хост
# 7     продажа          жанр    аргумент          врач            копирование
# 8      услуга     мобильный        блок           ген                  бэкап
# 9   сотрудник     приставка        поле       лечение         восстановление
#
#     Topic # 06     Topic # 07        Topic # 08   Topic # 09   Topic # 10  \
# 0       камера     уязвимость       программист  космический       доклад
# 1     смартфон          атака  программирование      спутник  конференция
# 2      телефон   безопасность         сотрудник       ракета       спикер
# 3        экран  злоумышленник              тест       орбита  выступление
# 4      дисплей    вредоносный            знание         марс     участник
# 5        видео         защита              курс      аппарат        видео
# 6  аккумулятор     обновление            бизнес        земля      встреча
# 7        карта      атаковать      тестирование         луна  мероприятие
# 8           гб         угроза             книга      планета        слайд
# 9  регистратор          хакер          менеджер        полет    докладчик
#
#       ...              Topic # 16 Topic # 17   Topic # 18  \
# 0     ...                  память  вселенная       запрос
# 1     ...               процессор  галактика      таблица
# 2     ...                    диск    энергия  база данные
# 3     ...                    ядро     звезда       запись
# 4     ...      производительность    материя       индекс
# 5     ...                      гб  квантовый       строка
# 6     ...              накопитель     темный     страница
# 7     ...               компьютер     теория           бд
# 8     ...                  запись  излучение   выполнение
# 9     ...                     кеш     солнце         субд
#
#             Topic # 19    Topic # 20     Topic # 21      Topic # 22  \
# 0             блокчейн       принтер          робот           товар
# 1           транзакция        печать        ребенок          скидка
# 2         криптовалюта        станок  робототехника         магазин
# 3              биткойн      печатать         датчик            цена
# 4                 банк            мм     автомобиль      распродажа
# 5  технология блокчейн  производство       движение      покупатель
# 6           финансовый        деталь         машина         покупка
# 7                 блок       изделие           дрон  черный пятница
# 8             участник          слой    беспилотный         пятница
# 9               валюта    напечатать    манипулятор           заказ
#
#    Topic # 23    Topic # 24  Topic # 25
# 0        ключ         пакет      сигнал
# 1  сертификат        скрипт        звук
# 2      пароль        модуль     частота
# 3       домен         папка   усилитель
# 4       адрес   репозиторий       плата
# 5      запись     установка  напряжение
# 6       токен        сборка         ток
# 7  шифрование    директория       канал
# 8   сообщение        плагин    диапазон
# 9     учетный  конфигурация      датчик
#
# [10 rows x 25 columns]
#
# NMF 50:
#      Topic # 01    Topic # 02  Topic # 03  Topic # 04      Topic # 05  \
# 0     сотрудник          игра      строка      сигнал      дата центр
# 1        бизнес         игрок      массив       плата            дата
# 2           ита       игровой  переменный     частота           центр
# 3      заказчик        играть   указатель  напряжение  инфраструктура
# 4        деньги      персонаж    аргумент         ток        облачный
# 5      менеджер        движок  анализатор      датчик    оборудование
# 6  руководитель  игра который      символ     питание          услуга
# 7          офис          жанр   выражение     антенна          облако
# 8          план     приставка  компилятор       схема             цод
# 9       продажа      игра это       вызов    приемник       провайдер
#
#         Topic # 06    Topic # 07         Topic # 08   Topic # 09   Topic # 10  \
# 0           камера    уязвимость              книга  космический       доклад
# 1            видео    обновление             читать      спутник  конференция
# 2      регистратор      эксплойт             дизайн       ракета       спикер
# 3           съемка       драйвер        прочитывать       орбита  выступление
# 4         движение          патч             чтение         марс     участник
# 5  видеонаблюдение     атаковать           дизайнер      аппарат      встреча
# 6           датчик    привилегия              текст         луна  мероприятие
# 7         объектив  безопасность  прочитывать книга        земля        видео
# 8             кадр      уязвимый            перевод        полет        слайд
# 9       веб камера    исправлять               блог       космос    докладчик
#
#               ...                   Topic # 41         Topic # 42  \
# 0             ...                       пароль        сколько час
# 1             ...                         флаг    порекомендовать
# 2             ...                      учетный   профессиональный
# 3             ...               учетный запись       предпочитать
# 4             ...                        логин           менеджер
# 5             ...                      задание           бумажный
# 6             ...                  авторизация       пользоваться
# 7             ...                         порт            слушать
# 8             ...                        адрес  внутренний проект
# 9             ...                      вводить             музыка
#
#     Topic # 43              Topic # 44  Topic # 45    Topic # 46  \
# 0       лекция              автомобиль        блок     контейнер
# 1         курс             беспилотный  транзакция           нод
# 2      студент  беспилотный автомобиль     позиция  конфигурация
# 3        видео                водитель      менять       кластер
# 4  университет                  машина       длина    директория
# 5     биология               автопилот         хеш   репозиторий
# 6      занятие                  дорога       поезд          хост
# 7    профессор             беспилотник        поле     установка
# 8    поведение           автомобильный     счетчик        сборка
# 9        школа                грузовик  новый блок        запуск
#
#        Topic # 47    Topic # 48 Topic # 49                   Topic # 50
# 0          скрипт       принтер    телефон                        атака
# 1          плагин        печать      номер                 безопасность
# 2           папка        станок   оператор                       защита
# 3      директория      печатать     звонок                злоумышленник
# 4          запуск            мм      карта                  вредоносный
# 5          сборка        деталь      вызов                       угроза
# 6           архив  производство    абонент                        хакер
# 7      расширение       изделие       шлюз               информационный
# 8     репозиторий    напечатать     трафик  информационный безопасность
# 9  скрипт который       пластик        атс        вредоносный программа
#
# [10 rows x 50 columns]
#
# NMF 100:
#        Topic # 01    Topic # 02  Topic # 03  Topic # 04  \
# 0          бизнес          игра      массив       плата
# 1        заказчик       игровой      строка  напряжение
# 2             ита        играть  переменный         ток
# 3  бизнес процесс        движок    аргумент     питание
# 4    планирование  игра который   указатель  микросхема
# 5      требование     приставка  переменная       схема
# 6     технический          жанр  возвращать      корпус
# 7              тз          инди   выражение   светодиод
# 8       внедрение      игра это    алгоритм    резистор
# 9          услуга      персонаж        цикл  транзистор
#
#                Topic # 05   Topic # 06     Topic # 07    Topic # 08  \
# 0  виртуальный реальность     смартфон          атака      участник
# 1              реальность  аккумулятор  злоумышленник  соревнование
# 2             виртуальный      батарея    вредоносный       конкурс
# 3                гарнитур      зарядка         ботнет   конференция
# 4                    шлем          мач        ботнуть       участие
# 5    дополнять реальность       гаджет          хакер       хакатон
# 6               дополнять           гб       заражать    победитель
# 7                    очки       корпус         жертва       задание
# 8               индустрия        заряд         защита   организатор
# 9                 контент       сканер           банк   мероприятие
#
#     Topic # 09   Topic # 10        ...               Topic # 91  \
# 0         марс       доклад        ...              регистратор
# 1  космический  конференция        ...                    видео
# 2      аппарат       спикер        ...                   запись
# 3        полет      встреча        ...                  глонасс
# 4         луна  выступление        ...                    рубль
# 5       миссия  мероприятие        ...                китайский
# 6       космос       андрей        ...                   съемка
# 7        земля    обсуждать        ...         видеорегистратор
# 8    астронавт    докладчик        ...                    ролик
# 9         зонд    александр        ...                     кадр
#
#       Topic # 92     Topic # 93        Topic # 94            Topic # 95  \
# 0      сотрудник         трафик          страница             мобильный
# 1           офис  маршрутизатор             стиль  мобильный приложение
# 2       работник          канал           контент  мобильный устройство
# 3       менеджер      провайдер         заголовок                платеж
# 4   руководитель        сетевой      веб страница  разработка мобильный
# 5  корпоративный       протокол          просмотр              нативный
# 6         отпуск        маршрут             текст              дайджест
# 7      удаленный          адрес  страница который               покупка
# 8       зарплата         кабель  главный страница           уведомление
# 9       директор     коммутатор        трансляция          тестирование
#
#    Topic # 96    Topic # 97       Topic # 98          Topic # 99  \
# 0     ноутбук     квантовый          станция           процессор
# 1       экран       частица  базовый станция              память
# 2  клавиатура         фотон          базовый  производительность
# 3     дисплей        хокинг          антенна                 кеш
# 4          гб  криптография          абонент                  гб
# 5       ридер     излучение  рабочий станция                ядро
# 6   подсветка   черный дыра            иначе          инструкция
# 7   компьютер        теория          мегафон         архитектура
# 8    дюймовый  пространство            линия  оперативный память
# 9  разрешение        физика           трекер             регистр
#
#         Topic # 100
# 0           ребенок
# 1             школа
# 2          родитель
# 3            ученик
# 4           учитель
# 5          школьник
# 6          взрослый
# 7          обучение
# 8  программирование
# 9     робототехника
#
# [10 rows x 100 columns]

# %% [markdown]
# Результаты `NMF` кажутся невероятно хорошими, можно даже сказать удивительными.
# Каждая из моделей выделяет полноценные, точные и лишенные шума темы, при этом все темы крайне осмысленны и не пересекаются друг с другом.
# Помимо этого, поражает их разнообразие и, самое главное, сохраняющаяся при этом точность, полноценность и гомогенность даже самых узких тем (от кибер-безопасности и VR до тематики конференций или видеорегистраторов).
# Думаю, здесь нет смысла пытаться выделять топ-3 темы, потому что разнообразие, точность и наполнение тем поражает, все они очень хороши.
# Как мне кажется, (на этих данных, по крайней мере, и при прочих равных) `NMF` колоссально превосходит по качеству `LDA`, настолько, что они едва ли кажутся сравнимыми.
